# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("top_insta_influencers_data.csv")
data
# Out:
#      rank channel_info  influence_score  posts followers avg_likes  \
# 0       1    cristiano               92   3.3k    475.8m      8.7m
# 1       2  kyliejenner               91   6.9k    366.2m      8.3m
# 2       3     leomessi               90  0.89k    357.3m      6.8m
# 3       4  selenagomez               93   1.8k    342.7m      6.2m
# 4       5      therock               91   6.8k    334.1m      1.9m
# ..    ...          ...              ...    ...       ...       ...
# 195   196    iambeckyg               71   2.3k     33.2m    623.8k
# 196   197   nancyajram               81   3.8k     33.2m    390.4k
# 197   198  luansantana               79  0.77k     33.2m    193.3k
# 198   199    nickjonas               78   2.3k     33.0m    719.6k
# 199   200    raisa6690               80   4.2k     32.8m    232.2k
#
#     60_day_eng_rate new_post_avg_like total_likes        country
# 0             1.39%              6.5m       29.0b          Spain
# ...

# %%
for channel in data["channel_info"]:
    print (channel)
# Out:
# cristiano
# kyliejenner
# leomessi
# selenagomez
# therock
# kimkardashian
# arianagrande
# beyonce
# khloekardashian
# justinbieber
# kendalljenner
# natgeo
# nike
# taylorswift
# jlo
# virat.kohli
# nickiminaj
# kourtneykardash
# mileycyrus
# neymarjr
# katyperry
# kevinhart4real
# zendaya
# iamcardib
# ddlovato
# badgalriri
# kingjames
# theellenshow
# realmadrid
# champagnepapi
# chrisbrownofficial
# fcbarcelona
# billieeilish
# dualipa
# gal_gadot
# vindiesel
# nasa
# priyankachopra
# lalalalisa_m
# Shakira
# snoopdogg
# gigihadid
# davidbeckham
# shraddhakapoor
# victoriassecret
# k.mbappe
# nehakakkar
# nba
# shawnmendes
# jennierubyjane
# narendramodi
# aliaabhatt
# deepikapadukone
# tomholland2013
# ronaldinho
# emmawatson
# bts.bighitofficial
# katrinakaif
# marvel
# justintimberlake
# camila_cabello
# willsmith
# raffinagita1717
# anitta
# sooyaaa__
# maluma
# akshaykumar
# jacquelinef143
# psg
# roses_are_rosie
# manchesterunited
# anushkasharma
# whinderssonnunes
# 9gag
# ...

# %% [markdown]
# # .iterrows()
#
# method in pandas to iterate over the rows of a DataFrame. It returns an iterator that generates a tuple for each row, where:
#
# The first element of the tuple is the row's index.
#
# The second element is a pandas Series object representing the row's data.
#
# Example:

# %%
for channel, followers in data[["channel_info", "followers"]].iterrows():
    print (channel, followers)
# Out:
# 0 channel_info    cristiano
# followers          475.8m
# Name: 0, dtype: object
# 1 channel_info    kyliejenner
# followers            366.2m
# Name: 1, dtype: object
# 2 channel_info    leomessi
# followers         357.3m
# Name: 2, dtype: object
# 3 channel_info    selenagomez
# followers            342.7m
# Name: 3, dtype: object
# 4 channel_info    therock
# followers        334.1m
# Name: 4, dtype: object
# 5 channel_info    kimkardashian
# followers              329.2m
# Name: 5, dtype: object
# 6 channel_info    arianagrande
# followers             327.7m
# Name: 6, dtype: object
# 7 channel_info    beyonce
# followers        272.8m
# Name: 7, dtype: object
# 8 channel_info    khloekardashian
# followers                268.3m
# Name: 8, dtype: object
# 9 channel_info    justinbieber
# followers             254.5m
# Name: 9, dtype: object
# 10 channel_info    kendalljenner
# followers              254.0m
# Name: 10, dtype: object
# 11 channel_info    natgeo
# ...

# %% [markdown]
# # iter()
#
# - Converts an iterable (like a list,column, tuple, or range) into an iterator, which generates elements on demand.
# - An iterator in Python is an object that allows you to loop through all the elements in a collection

# %%
variable = iter(data["channel_info"])

# %%
print(next(variable))
print(next(variable))
print(next(variable))
print(next(variable))
# Out:
# cristiano
# kyliejenner
# leomessi
# selenagomez

# %% [markdown]
# # enumerate()
# - its also an iterable
# -  function in Python, built-in tool that adds a counter (index) to any iterable and returns it as an enumerate object. It's often used in loops when you need both the index and the value of each item in the iterable

# %%
data.head(2)
# Out:
#    rank channel_info  influence_score posts followers avg_likes  \
# 0     1    cristiano               92  3.3k    475.8m      8.7m
# 1     2  kyliejenner               91  6.9k    366.2m      8.3m
#
#   60_day_eng_rate new_post_avg_like total_likes        country
# 0           1.39%              6.5m       29.0b          Spain
# 1           1.62%              5.9m       57.4b  United States

# %%
for index ,channel in enumerate(data["channel_info"]):
    print (f"Index: {index}, Channel: {channel}")
# Out:
# Index: 0, Channel: cristiano
# Index: 1, Channel: kyliejenner
# Index: 2, Channel: leomessi
# Index: 3, Channel: selenagomez
# Index: 4, Channel: therock
# Index: 5, Channel: kimkardashian
# Index: 6, Channel: arianagrande
# Index: 7, Channel: beyonce
# Index: 8, Channel: khloekardashian
# Index: 9, Channel: justinbieber
# Index: 10, Channel: kendalljenner
# Index: 11, Channel: natgeo
# Index: 12, Channel: nike
# Index: 13, Channel: taylorswift
# Index: 14, Channel: jlo
# Index: 15, Channel: virat.kohli
# Index: 16, Channel: nickiminaj
# Index: 17, Channel: kourtneykardash
# Index: 18, Channel: mileycyrus
# Index: 19, Channel: neymarjr
# Index: 20, Channel: katyperry
# Index: 21, Channel: kevinhart4real
# Index: 22, Channel: zendaya
# Index: 23, Channel: iamcardib
# Index: 24, Channel: ddlovato
# Index: 25, Channel: badgalriri
# Index: 26, Channel: kingjames
# Index: 27, Channel: theellenshow
# Index: 28, Channel: realmadrid
# Index: 29, Channel: champagnepapi
# ...

# %%
for index ,channel in enumerate(data["channel_info"]):
    print (index,channel)
# Out:
# 0 cristiano
# 1 kyliejenner
# 2 leomessi
# 3 selenagomez
# 4 therock
# 5 kimkardashian
# 6 arianagrande
# 7 beyonce
# 8 khloekardashian
# 9 justinbieber
# 10 kendalljenner
# 11 natgeo
# 12 nike
# 13 taylorswift
# 14 jlo
# 15 virat.kohli
# 16 nickiminaj
# 17 kourtneykardash
# 18 mileycyrus
# 19 neymarjr
# 20 katyperry
# 21 kevinhart4real
# 22 zendaya
# 23 iamcardib
# 24 ddlovato
# 25 badgalriri
# 26 kingjames
# 27 theellenshow
# 28 realmadrid
# 29 champagnepapi
# 30 chrisbrownofficial
# 31 fcbarcelona
# 32 billieeilish
# 33 dualipa
# 34 gal_gadot
# 35 vindiesel
# 36 nasa
# 37 priyankachopra
# 38 lalalalisa_m
# 39 Shakira
# 40 snoopdogg
# 41 gigihadid
# 42 davidbeckham
# 43 shraddhakapoor
# 44 victoriassecret
# 45 k.mbappe
# 46 nehakakkar
# 47 nba
# 48 shawnmendes
# 49 jennierubyjane
# 50 narendramodi
# 51 aliaabhatt
# 52 deepikapadukone
# 53 tomholland2013
# 54 ronaldinho
# 55 emmawatson
# 56 bts.bighitofficial
# 57 katrinakaif
# 58 marvel
# 59 justintimberlake
# 60 camila_cabello
# ...

# %%
# can also specify where the index starts 
for index ,channel in enumerate(data["channel_info"], start = 10):
    print (f"Index: {index}, Channel: {channel}")
# Out:
# Index: 10, Channel: cristiano
# Index: 11, Channel: kyliejenner
# Index: 12, Channel: leomessi
# Index: 13, Channel: selenagomez
# Index: 14, Channel: therock
# Index: 15, Channel: kimkardashian
# Index: 16, Channel: arianagrande
# Index: 17, Channel: beyonce
# Index: 18, Channel: khloekardashian
# Index: 19, Channel: justinbieber
# Index: 20, Channel: kendalljenner
# Index: 21, Channel: natgeo
# Index: 22, Channel: nike
# Index: 23, Channel: taylorswift
# Index: 24, Channel: jlo
# Index: 25, Channel: virat.kohli
# Index: 26, Channel: nickiminaj
# Index: 27, Channel: kourtneykardash
# Index: 28, Channel: mileycyrus
# Index: 29, Channel: neymarjr
# Index: 30, Channel: katyperry
# Index: 31, Channel: kevinhart4real
# Index: 32, Channel: zendaya
# Index: 33, Channel: iamcardib
# Index: 34, Channel: ddlovato
# Index: 35, Channel: badgalriri
# Index: 36, Channel: kingjames
# Index: 37, Channel: theellenshow
# Index: 38, Channel: realmadrid
# Index: 39, Channel: champagnepapi
# ...

# %% [markdown]
# # zip()
# - The zip() function in Python is used to combine two or more iterables (e.g., lists, tuples, strings) into a single iterator of tuples

# %%
data["channel_info"]
# Out:
# 0        cristiano
# 1      kyliejenner
# 2         leomessi
# 3      selenagomez
# 4          therock
#           ...
# 195      iambeckyg
# 196     nancyajram
# 197    luansantana
# 198      nickjonas
# 199      raisa6690
# Name: channel_info, Length: 200, dtype: object

# %%
data["60_day_eng_rate"]
# Out:
# 0      1.39%
# 1      1.62%
# 2      1.24%
# 3      0.97%
# 4      0.20%
#        ...
# 195    1.40%
# 196    0.64%
# 197    0.26%
# 198    1.42%
# 199    0.30%
# Name: 60_day_eng_rate, Length: 200, dtype: object

# %%
for channel, rate in zip(data["channel_info"], data["60_day_eng_rate"]):
    print(f" Channel : {channel}, Rate :{rate}")
# Out:
#  Channel : cristiano, Rate :1.39%
#  Channel : kyliejenner, Rate :1.62%
#  Channel : leomessi, Rate :1.24%
#  Channel : selenagomez, Rate :0.97%
#  Channel : therock, Rate :0.20%
#  Channel : kimkardashian, Rate :0.88%
#  Channel : arianagrande, Rate :1.20%
#  Channel : beyonce, Rate :0.76%
#  Channel : khloekardashian, Rate :0.35%
#  Channel : justinbieber, Rate :0.59%
#  Channel : kendalljenner, Rate :2.04%
#  Channel : natgeo, Rate :0.07%
#  Channel : nike, Rate :0.08%
#  Channel : taylorswift, Rate :1.01%
#  Channel : jlo, Rate :0.62%
#  Channel : virat.kohli, Rate :0.96%
#  Channel : nickiminaj, Rate :0.53%
#  Channel : kourtneykardash, Rate :0.67%
#  Channel : mileycyrus, Rate :0.51%
#  Channel : neymarjr, Rate :1.09%
#  Channel : katyperry, Rate :0.16%
#  Channel : kevinhart4real, Rate :0.08%
#  Channel : zendaya, Rate :3.17%
#  Channel : iamcardib, Rate :1.10%
#  Channel : ddlovato, Rate :0.27%
#  Channel : badgalriri, Rate :0.02%
#  Channel : kingjames, Rate :0.92%
# ...

# %% [markdown]
# example 2

# %%
fruits = ["apple", "banana", "cherry"]  # List of fruit names
numbers = [1, 2, 3]                     # List of numbers
colors = ["red", "blue", "green"]       # List of colors

# %%
zipped = zip(fruits, numbers, colors)
print(list(zipped))

# will always have to zpecify list when zip something
# Out:
# [('apple', 1, 'red'), ('banana', 2, 'blue'), ('cherry', 3, 'green')]

# %% [markdown]
# # unpack with *
#
# In Python, unpacking means breaking an iterable (like a list, tuple, or dictionary) into its individual elements so they can be used as separate values

# %%
unzipped = zip(*zipped)

# %% [markdown]
# # iterate over data using chunksize =

# %%
result = []
for chunk in pd.read_csv("top_insta_influencers_data.csv", chunksize = 20):
    result.append(chunk)
print(result)
# Out:
# [    rank     channel_info  influence_score  posts followers avg_likes  \
# 0      1        cristiano               92   3.3k    475.8m      8.7m
# 1      2      kyliejenner               91   6.9k    366.2m      8.3m
# 2      3         leomessi               90  0.89k    357.3m      6.8m
# 3      4      selenagomez               93   1.8k    342.7m      6.2m
# 4      5          therock               91   6.8k    334.1m      1.9m
# 5      6    kimkardashian               91   5.6k    329.2m      3.5m
# 6      7     arianagrande               92   5.0k    327.7m      3.7m
# 7      8          beyonce               92   2.0k    272.8m      3.6m
# 8      9  khloekardashian               89   4.1k    268.3m      2.4m
# 9     10     justinbieber               91   7.4k    254.5m      1.9m
# 10    11    kendalljenner               90  0.66k    254.0m      5.5m
# 11    12           natgeo               91  10.0k    237.0m    302.2k
# ...

# %%
result2 = []
for chunk in pd.read_csv("top_insta_influencers_data.csv", chunksize = 20):
    result2.append(sum(chunk["influence_score"]))
total = sum(result2)
print(total)
# Out:
# 16364

# %% [markdown]
# # map
# - Applies a specified function to each item in an iterable (like a list, tuple, or set) and returns a map object, which is an iterator. It's particularly useful for transforming data in an iterable without the need for a loop.

# %%
# Example: Convert a list of numbers to their squares
numbers = [1, 2, 3, 4, 5]
squares = map(lambda x: x ** 2, numbers)

# Convert the map object to a list for viewing
print(list(squares))
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# # items
#
# - used to iterate over keys and values pairs in dictionaries. Returns a tuple of the key and value.

# %%
my_dict = {'name': 'Angeles', 'age': 25, 'city': 'San Diego'}

for key, value in my_dict.items():
    print(f"{key}: {value}")
# Out:
# name: Angeles
# age: 25
# city: San Diego
